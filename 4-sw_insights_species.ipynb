# %% [markdown]
# #   Insights STARS WARS - Teste Prático Globo

# %%
import os
import shutil
import duckdb

duckdb_conn = duckdb.connect(database=":memory:", read_only=False)

def mover_arquivos_parquet():
    if not os.path.exists('parquet'):
        os.makedirs('parquet')
    [shutil.move(f, 'parquet') for f in os.listdir('.') if f.endswith('.parquet')]

mover_arquivos_parquet()

df_films = duckdb_conn.from_parquet("./parquet/films_data.parquet").to_df()
df_people = duckdb_conn.from_parquet("./parquet/people_data.parquet").to_df()
df_films = duckdb_conn.from_parquet("./parquet/films_data.parquet").to_df()
df_starships = duckdb_conn.from_parquet("./parquet/starships_data.parquet").to_df()
df_vehicles = duckdb_conn.from_parquet("./parquet/vehicles_data.parquet").to_df()
df_planets = duckdb_conn.from_parquet("./parquet/planets_data.parquet").to_df()
df_species = duckdb_conn.from_parquet("./parquet/species_data.parquet").to_df()

# %%
query = """
SELECT *
FROM df_species as s
limit 5
;

"""
result = duckdb_conn.execute(query)
result.df()
# Out:
#      name classification designation average_height  \
# 0   Human         mammal    sentient            180
# 1   Droid     artificial    sentient            n/a
# 2  Wookie         mammal    sentient            210
# 3  Rodian       sentient   reptilian            170
# 4    Hutt      gastropod    sentient            300
#
#                          skin_colors                hair_colors  \
# 0  caucasian, black, asian, hispanic  blonde, brown, black, red
# 1                                n/a                        n/a
# 2                               gray               black, brown
# 3                        green, blue                        n/a
# 4                  green, brown, tan                        n/a
#
#                                 eye_colors average_lifespan  \
# 0   brown, blue, green, hazel, grey, amber              120
# 1                                      n/a       indefinite
# 2  blue, green, yellow, brown, golden, red              400
# 3                                    black          unknown
# 4                              yellow, red             1000
#
#                            homeworld        language  \
# 0   https://swapi.dev/api/planets/9/  Galactic Basic
# 1                               None             n/a
# 2  https://swapi.dev/api/planets/14/      Shyriiwook
# 3  https://swapi.dev/api/planets/23/   Galatic Basic
# 4  https://swapi.dev/api/planets/24/         Huttese
#
#                                               people  \
# 0  [https://swapi.dev/api/people/66/, https://swa...
# 1  [https://swapi.dev/api/people/2/, https://swap...
# 2  [https://swapi.dev/api/people/13/, https://swa...
# 3                 [https://swapi.dev/api/people/15/]
# 4                 [https://swapi.dev/api/people/16/]
#
#                                                films  \
# 0  [https://swapi.dev/api/films/1/, https://swapi...
# 1  [https://swapi.dev/api/films/1/, https://swapi...
# 2  [https://swapi.dev/api/films/1/, https://swapi...
# 3                   [https://swapi.dev/api/films/1/]
# 4  [https://swapi.dev/api/films/1/, https://swapi...
#
#                        created                       edited  \
# 0  2014-12-10T13:52:11.567000Z  2014-12-20T21:36:42.136000Z
# 1  2014-12-10T15:16:16.259000Z  2014-12-20T21:36:42.139000Z
# 2  2014-12-10T16:44:31.486000Z  2014-12-20T21:36:42.142000Z
# 3  2014-12-10T17:05:26.471000Z  2014-12-20T21:36:42.144000Z
# 4  2014-12-10T17:12:50.410000Z  2014-12-20T21:36:42.146000Z
#
#                                 url detail
# 0  https://swapi.dev/api/species/1/   None
# 1  https://swapi.dev/api/species/2/   None
# 2  https://swapi.dev/api/species/3/   None
# 3  https://swapi.dev/api/species/4/   None
# 4  https://swapi.dev/api/species/5/   None

# %% [markdown]
# ## Distribuição de Espécies por Planeta

# %%
query = """
SELECT p.name as Planeta, s.name as Especie, COUNT(s.name) AS Qtd_Especie
FROM df_species as s
JOIN df_planets as p
ON s.homeworld = p.url
GROUP BY p.name, s.name;

"""
result = duckdb_conn.execute(query)
result.df()
# Out:
#            Planeta         Especie  Qtd_Especie
# 0             Tund           Toong            1
# 1          Iktotch        Iktotchi            1
# 2            Skako         Skakoan            1
# 3       Muunilinst            Muun            1
# 4            Endor            Ewok            1
# 5        Coruscant           Human            1
# 6        Nal Hutta            Hutt            1
# 7          unknown  Yoda's species            1
# 8          Sullust       Sullustan            1
# 9          Troiken           Xexto            1
# 10           Dorin         Kel Dor            1
# 11           Kalee         Kaleesh            1
# 12        Geonosis       Geonosian            1
# 13  Cato Neimoidia       Neimodian            1
# 14       Trandosha      Trandoshan            1
# 15        Mon Cala    Mon Calamari            1
# 16       Malastare             Dug            1
# 17         Vulpter      Vulptereen            1
# 18            Ojom        Besalisk            1
# 19          Ryloth         Twi'lek            1
# 20     Aleen Minor          Aleena            1
# 21         Quermia        Quermian            1
# 22           Naboo          Gungan            1
# 23          Kamino        Kaminoan            1
# 24        Toydaria       Toydarian            1
# 25           Rodia          Rodian            1
# 26        Champala        Chagrian            1
# 27          Utapau          Pau'an            1
# 28         Tholoth      Tholothian            1
# 29           Zolan        Clawdite            1
# 30           Shili         Togruta            1
# 31           Cerea          Cerean            1
# 32        Kashyyyk          Wookie            1
# 33     Glee Anselm        Nautolan            1
# 34        Iridonia          Zabrak            1
# 35          Mirial        Mirialan            1

# %% [markdown]
# ## Relação entre Espécies e Filmes

# %%
query = """
SELECT
    s.name AS Especie,
    COUNT(DISTINCT f.title) AS Qtd_Filmes
FROM
    df_species as s
JOIN
    df_films as f 
ON ARRAY_CONTAINS(f.species, s.url)
GROUP BY
    s.name

"""
result = duckdb_conn.execute(query)
result.df()
# Out:
#            Especie  Qtd_Filmes
# 0             Muun           2
# 1        Geonosian           2
# 2          Kaleesh           1
# 3             Hutt           2
# 4            Xexto           1
# 5       Tholothian           2
# 6         Iktotchi           2
# 7            Human           6
# 8           Gungan           2
# 9         Mirialan           2
# 10        Clawdite           2
# 11       Sullustan           1
# 12          Rodian           1
# 13       Neimodian           1
# 14        Quermian           2
# 15       Toydarian           2
# 16        Nautolan           1
# 17        Kaminoan           1
# 18         Togruta           2
# 19      Vulptereen           1
# 20          Wookie           4
# 21  Yoda's species           5
# 22          Aleena           1
# 23          Pau'an           1
# 24             Dug           1
# 25        Besalisk           1
# 26         Skakoan           2
# 27         Kel Dor           2
# 28           Toong           2
# 29          Zabrak           1
# 30            Ewok           1
# 31         Twi'lek           4
# 32           Droid           6
# 33          Cerean           2
# 34        Chagrian           2
# 35      Trandoshan           1
# 36    Mon Calamari           1

# %% [markdown]
# ## Comparação de Características Físicas

# %%
query = """
SELECT
    classification as Classificação,
    ROUND(AVG(TRY_CAST(REPLACE(REPLACE(REPLACE(average_height, 'unknown', '0'), 'n/a', '0'), 'indefinite', '0') AS FLOAT)),2) AS Altura_Media,
    ROUND(AVG(TRY_CAST(REPLACE(REPLACE(REPLACE(average_lifespan, 'unknown', '0'), 'n/a', '0'), 'indefinite', '0') AS FLOAT)),2) AS Expectativa_Med_Vida
FROM
    df_species
WHERE
    classification not in ('unknown','n/a','indefinite') 
GROUP BY
    classification;
"""
result = duckdb_conn.execute(query)
result.df()
# Out:
#   Classificação  Altura_Media  Expectativa_Med_Vida
# 0      sentient        170.00                  0.00
# 1       reptile        150.00                 53.00
# 2     amphibian        186.33                 37.50
# 3     insectoid        178.00                  0.00
# 4        mammal        144.75                155.69
# 5    artificial          0.00                  0.00
# 6     reptilian        180.00                 70.00
# 7     gastropod        300.00               1000.00
# 8       mammals        200.00                  0.00

# %% [markdown]
# ## Idiomas

# %%
query = """
SELECT
    language as Lingua,
    COUNT(DISTINCT name) AS Qtd_Especies
FROM
    df_species
WHERE language not in('unknown', 'n/a') 
GROUP BY
    language;

"""
result = duckdb_conn.execute(query)
result.df()
# Out:
#             Lingua  Qtd_Especies
# 0       vulpterish             1
# 1         Twi'leki             1
# 2         besalisk             1
# 3     Gungan basic             1
# 4           Dugese             1
# 5          Xextese             1
# 6             Dosh             1
# 7        Toydarian             1
# 8         Quermian             1
# 9        Sullutese             1
# 10        Kaminoan             1
# 11   Galatic Basic             1
# 12            Muun             1
# 13      Iktotchese             1
# 14         Togruti             1
# 15       Neimoidia             1
# 16      Shyriiwook             1
# 17       Geonosian             1
# 18         Kaleesh             1
# 19         Nautila             1
# 20        Mirialan             1
# 21        Clawdite             1
# 22  Galactic Basic             1
# 23         Chagria             1
# 24         Huttese             1
# 25          Aleena             1
# 26         Zabraki             1
# 27          Cerean             1
# 28          Tundan             1
# 29  Mon Calamarian             1
# 30         Utapese             1
# 31         Ewokese             1
# 32  Galactic basic             1
# 33         Kel Dor             1
# 34         Skakoan             1

# %% [markdown]
# ## Qtde de Especies por Filmes

# %%
query = """
SELECT
    f.title AS Filme,
    COUNT(DISTINCT s.name) AS Qtde_Especie
FROM
    df_species as s
JOIN
    df_films as f 
ON ARRAY_CONTAINS(f.species, s.url)
GROUP BY
    f.title;

"""
result = duckdb_conn.execute(query)
result.df()
# Out:
#                      Filme  Qtde_Especie
# 0       The Phantom Menace            20
# 1               A New Hope             5
# 2       Return of the Jedi             9
# 3     Attack of the Clones            14
# 4  The Empire Strikes Back             5
# 5      Revenge of the Sith            20
